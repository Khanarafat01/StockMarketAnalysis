# %%
import pandas as pd
import numpy as np
df = pd.read_csv("all_stock_data.csv")
df.head()
# Out:
#          Date Ticker        Open        High         Low       Close    Volume
# 0  2023-10-02   AAPL  169.974219  173.031811  169.686320  172.485809  52164500
# 1  2023-10-03   AAPL  171.006634  172.366676  169.577124  171.145615  49594600
# 2  2023-10-04   AAPL  169.845131  172.942440  169.726009  172.396439  53020300
# 3  2023-10-05   AAPL  172.525514  174.173439  171.423589  173.637375  48527900
# 4  2023-10-06   AAPL  172.535439  176.694955  171.919940  176.198593  57224100

# %%
df.isnull().sum()
# Out:
# Date      0
# Ticker    0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1240.000000  1240.000000  1240.000000  1240.000000  1.240000e+03
# mean    232.620584   235.179837   230.227306   232.862025  7.884978e+07
# std     137.041995   138.531984   135.564491   137.055535  1.451126e+08
# min      40.431259    40.860062    39.211823    40.307320  1.404700e+06
# 25%     142.427223   143.659870   141.256002   142.793056  9.147450e+06
# 50%     178.590944   180.266732   177.155482   178.763397  2.541455e+07
# 75%     330.783504   335.241492   327.864301   332.629814  5.940598e+07
# max     630.650024   634.390015   623.159973   629.239990  1.142269e+09

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Correlation metrix

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Histogram for numeric columns

# %%
df.hist(bins=30, figsize=(15,10))
plt.suptitle('Histogram of Numeric Features')
plt.show()

# %% [markdown]
# ### Boxplots for each numeric column

# %%
for col in df.select_dtypes(include=np.number).columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()
